# %% [markdown]
# # 作業目標:¶
# 利用手寫辨識資料說明MLP 中, 神經網路層的多寡跟預測結果的差異

# %% [markdown]
# # 作業重點:
# [練習]請嘗試新增一層或兩層看看最後預測結果是否有差異
# model.add(Dense(units=256, input_dim=784, kernel_initializer='normal', activation='relu'))

# %% [markdown]
# # 資料預處理

# %%
from tensorflow.keras.utils import to_categorical
import numpy as np
np.random.seed(10)

# %%
#載入手寫辨識的資料集
from tensorflow.keras.datasets import mnist
(x_train_image,y_train_label),\
(x_test_image,y_test_label)= mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
#指定測試集與訓練資料集
x_Train =x_train_image.reshape(60000, 784).astype('float32')
x_Test = x_test_image.reshape(10000, 784).astype('float32')

# %%
# normalize inputs from 0-255 to 0-1
x_Train_normalize = x_Train / 255
x_Test_normalize = x_Test / 255

# %%
#把LABEL轉成NUMERICAL Categorical 
y_Train_OneHot = to_categorical(y_train_label)
y_Test_OneHot = to_categorical(y_test_label)

# %% [markdown]
# # 建立模型

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
#建立模型
model = Sequential()
model.add(Dense(units=256, input_dim=784, kernel_initializer='normal', activation='relu'))
model.add(Dense(units=256, input_dim=784, kernel_initializer='normal', activation='relu'))
model.add(Dense(units=10, kernel_initializer='normal', activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 訓練模型

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

# %%
train_history =model.fit(x=x_Train_normalize,
                         y=y_Train_OneHot,validation_split=0.2, 
                         epochs=10, batch_size=32,verbose=1)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2386 - accuracy: 0.9291 - val_loss: 0.1400 - val_accuracy: 0.9567
# Epoch 2/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0920 - accuracy: 0.9718 - val_loss: 0.0960 - val_accuracy: 0.9716
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0646 - accuracy: 0.9794 - val_loss: 0.0846 - val_accuracy: 0.9757
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0472 - accuracy: 0.9850 - val_loss: 0.1016 - val_accuracy: 0.9714
# Epoch 5/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0379 - accuracy: 0.9873 - val_loss: 0.0887 - val_accuracy: 0.9754
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0303 - accuracy: 0.9898 - val_loss: 0.1021 - val_accuracy: 0.9737
# Epoch 7/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0237 - accuracy: 0.9922 - val_loss: 0.0965 - val_accuracy: 0.9777
# Epoch 8/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0228 - accuracy: 0.9924 - val_loss: 0.1067 - val_accuracy: 0.9760
# Epoch 9/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0171 - accuracy: 0.9946 - val_loss: 0.1402 - val_accuracy: 0.9712
# Epoch 10/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0177 - accuracy: 0.9943 - val_loss: 0.1134 - val_accuracy: 0.9775

# %% [markdown]
# # 以圖形顯示訓練過程

# %%
import matplotlib.pyplot as plt
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

# %%
show_train_history(train_history,'accuracy','val_accuracy')

# %%
show_train_history(train_history,'loss','val_loss')

# %% [markdown]
# # 評估模型準確率

# %%
scores = model.evaluate(x_Test_normalize, y_Test_OneHot)
print()
print('accuracy=',scores[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1062 - accuracy: 0.9777
#
# accuracy= 0.9776999950408936

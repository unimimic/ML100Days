# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix

# Record_fp_tp
class Record_tp_tn(Callback):
    """Code Here
    撰寫一個紀錄 ture positive 與 true negative 數量的 callbacks    
    """
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = [ "val_tp", "val_tn"]
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        cm = confusion_matrix(y_true = y_true, y_pred = y_pred)
        logs["val_tp"] = cm[1][1]
        logs["val_tn"] = cm[0][0]
        
rec_tptn = Record_tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history["val_tp"]
valid_tn = model.history.history["val_tn"]
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 1s 30us/step - loss: 2.2239 - accuracy: 0.2687 - val_loss: 2.1352 - val_accuracy: 0.2050
# Epoch 2/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.7389 - accuracy: 0.3933 - val_loss: 1.9698 - val_accuracy: 0.3008
# Epoch 3/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.6102 - accuracy: 0.4354 - val_loss: 1.8298 - val_accuracy: 0.3637
# Epoch 4/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.5337 - accuracy: 0.4619 - val_loss: 1.7284 - val_accuracy: 0.3973
# Epoch 5/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.4798 - accuracy: 0.4816 - val_loss: 1.6376 - val_accuracy: 0.4233
# Epoch 6/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.4346 - accuracy: 0.4970 - val_loss: 1.5815 - val_accuracy: 0.4411
# Epoch 7/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.3947 - accuracy: 0.5122 - val_loss: 1.5553 - val_accuracy: 0.4483
# Epoch 8/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.3586 - accuracy: 0.5273 - val_loss: 1.5143 - val_accuracy: 0.4615
# Epoch 9/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.3250 - accuracy: 0.5371 - val_loss: 1.4996 - val_accuracy: 0.4727
# Epoch 10/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.2948 - accuracy: 0.5504 - val_loss: 1.4971 - val_accuracy: 0.4722
# Epoch 11/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.2676 - accuracy: 0.5611 - val_loss: 1.4800 - val_accuracy: 0.4746
# Epoch 12/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.2403 - accuracy: 0.5701 - val_loss: 1.4722 - val_accuracy: 0.4786
# Epoch 13/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.2148 - accuracy: 0.5787 - val_loss: 1.4680 - val_accuracy: 0.4841
# Epoch 14/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.1911 - accuracy: 0.5905 - val_loss: 1.4805 - val_accuracy: 0.4748
# Epoch 15/25
# 50000/50000 [==============================] - 1s 22us/step - loss: 1.1663 - accuracy: 0.5996 - val_loss: 1.4658 - val_accuracy: 0.4854
# Epoch 16/25
# 50000/50000 [==============================] - 1s 22us/step - loss: 1.1429 - accuracy: 0.6075 - val_loss: 1.4643 - val_accuracy: 0.4824
# Epoch 17/25
# 50000/50000 [==============================] - 1s 22us/step - loss: 1.1186 - accuracy: 0.6170 - val_loss: 1.4595 - val_accuracy: 0.4889
# Epoch 18/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.0951 - accuracy: 0.6265 - val_loss: 1.4695 - val_accuracy: 0.4875
# Epoch 19/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.0746 - accuracy: 0.6333 - val_loss: 1.4685 - val_accuracy: 0.4916
# Epoch 20/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.0529 - accuracy: 0.6427 - val_loss: 1.4672 - val_accuracy: 0.4889
# Epoch 21/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.0308 - accuracy: 0.6502 - val_loss: 1.4630 - val_accuracy: 0.4931
# Epoch 22/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 1.0108 - accuracy: 0.6585 - val_loss: 1.4541 - val_accuracy: 0.4933
# Epoch 23/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 0.9893 - accuracy: 0.6671 - val_loss: 1.4676 - val_accuracy: 0.4892
# Epoch 24/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 0.9685 - accuracy: 0.6742 - val_loss: 1.4689 - val_accuracy: 0.4956
# Epoch 25/25
# 50000/50000 [==============================] - 1s 23us/step - loss: 0.9487 - accuracy: 0.6828 - val_loss: 1.4765 - val_accuracy: 0.4891

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
